# %% [markdown]
# # practice machine learning

# %% [markdown]
# # machine learning

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
from sklearn.datasets import load_digits
digits=load_digits()

# %%
digits
# Out:
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#         [ 0.,  0., 10., ..., 12.,  1.,  0.]]),
#  'target': array([0, 1, 2, ..., 8, 9, 8]),
#  'frame': None,
#  'feature_names': ['pixel_0_0',
#   'pixel_0_1',
#   'pixel_0_2',
#   'pixel_0_3',
#   'pixel_0_4',
#   'pixel_0_5',
#   'pixel_0_6',
#   'pixel_0_7',
#   'pixel_1_0',
#   'pixel_1_1',
#   'pixel_1_2',
#   'pixel_1_3',
#   'pixel_1_4',
#   'pixel_1_5',
#   'pixel_1_6',
#   'pixel_1_7',
#   'pixel_2_0',
#   'pixel_2_1',
#   'pixel_2_2',
#   'pixel_2_3',
#   'pixel_2_4',
#   'pixel_2_5',
#   'pixel_2_6',
#   'pixel_2_7',
#   'pixel_3_0',
#   'pixel_3_1',
#   'pixel_3_2',
#   'pixel_3_3',
#   'pixel_3_4',
#   'pixel_3_5',
#   'pixel_3_6',
#   'pixel_3_7',
#   'pixel_4_0',
#   'pixel_4_1',
#   'pixel_4_2',
#   'pixel_4_3',
# ...

# %%
images=digits.images
images.shape
images
data=digits.data
#digits.DESCR

# %%
target=digits.target
target.shape
# Out:
# (1797,)

# %%
#df=pd.DataFrame(data)
#df['target']=target
#df.head(2)

# %%
plt.imshow(images[1])
plt.text(0.05, 0.05,s=target[1],color='red',)
# Out:
# Text(0.05, 0.05, '1')

# %%
fig,ax=plt.subplots(10,10,figsize=(15,15),sharex=True,sharey=True)
for i,axes in enumerate(ax.flat):
    axes.imshow(images[i])
    axes.text(0.05,0.05,target[i])
plt.show()

# %%
count=0
for i in range(len(ytest)):
    print(ytest[i],'==',pred[i])
    if(ytest[i]==pred[i]):
        count+=1
percent=(count/len(ytest))*100
#print(percent)

# %%
from sklearn.model_selection import train_test_split
xtrain,ytrain,xtest,ytest=train_test_split(data,digits.target)
from sklearn.naive_bayes import  GaussianNB
model=GaussianNB()
model.fit(xtrain,xtest)
# Out:
# GaussianNB()

# %%
pred=model.predict(ytrain)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred,ytest)
# Out:
# 0.8377777777777777

# %%
from sklearn.metrics import confusion_matrix
matrix=confusion_matrix(pred,ytest)
sns.heatmap(matrix,annot=True,square=True)
plt.show()

# %%
fig,ax=plt.subplots(10,10,figsize=(15,15),sharex=True,sharey=True)
for i,axes in enumerate(ax.flat):
    axes.imshow(images[i],interpolation='nearest')
    axes.text(0.05,0.05,str(target[i]),transform=axes.transAxes,color='white'if(ytest[i]==pred[i]) else 'red')
plt.show()
